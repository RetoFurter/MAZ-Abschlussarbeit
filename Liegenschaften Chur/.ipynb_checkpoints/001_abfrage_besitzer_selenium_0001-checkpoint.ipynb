# %%
import requests
import os
import csv
import pandas as pd
import json
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from random import randint
from datetime import datetime
from datetime import timedelta
from selenium.webdriver.common.action_chains import ActionChains


###############
# ABFRAGE DER LIEGENSCHAFTENNUMMERN
###############
von = 15000
bis = 25000 # (inkl. Maladers)
###############
# ABFRAGE DER LIEGENSCHAFTENNUMMERN
###############

###############
# universale Pausenlänge
pause = 2
###############

###############
# Anzahl Schlaufen
durchlaeufe = 1
###############
    

    
for durchlauf in range(durchlaeufe):
    
    print('Durchlauf ' + str(durchlauf + 1) + ' von ' + str(durchlaeufe))
    
    
    ###############
    # nicht funktionierende Grundstuecknummern, weil falsch angewählt
    grundstueck_manuell_bearbeiten = []

    if 'Chur_manuell_bearbeiten.csv' in os.listdir('grundstuecke/'): #gar keine Grundstücke

        with open('grundstuecke/Chur_manuell_bearbeiten.csv', 'r') as csvfile: #nicht existent 
            for row in csv.reader(csvfile):
                if len(row) == 0:
                    grundstueck_manuell_bearbeiten.append(-1)
                grundstueck_manuell_bearbeiten.append(row[0])

        csvfile.close()

        os.remove('grundstuecke/Chur_manuell_bearbeiten.csv')







    driver = webdriver.Chrome('/usr/local/bin/chromedriver')

    driver.get('https://stadtplan.chur.ch/mapplus/chur/index.php?lang=de&basemap=av_schwarz&blop=1&x=2759663.1205041&y=1191084.0553479&zl=11&hl=0&layers=AV_Bauprojekte_bewilligt|AV_Baulinien&theme=1')
    time.sleep(5)




    # 1. Liegenschaft anzeigen, zur Anzeige des Detailfenster
    driver.find_element_by_id('solrsearchFirstParamSelect').clear()
    driver.find_element_by_id('solrsearchFirstParamSelect').send_keys("100")
    time.sleep(pause)

    eintraege = driver.find_elements_by_class_name('dijitReset.dijitMenuItem')
    for eintrag in eintraege:

    # für Grundstück 100, zum Einstieg
        if eintrag.text == "Grundstücknummer: 100":
            eintrag.click()
            time.sleep(pause)

    # Detailinfo einblenden
    driver.find_element_by_id('NeapoljsContainer').click()
    time.sleep(pause)



    # Liegeschaften abfragen   

    for liegenschaft_nr in range(von,bis): 

        abfragen = True


        if ('Chur_' + ('0000000000' + str(liegenschaft_nr))[-10:] + '.csv') in os.listdir('grundstuecke/'): # File schon vorhanden
            abfragen = False




        if abfragen:

            try:
                # Dictionary vorbereiten für einzelnen Grundbesitz
                grundbesitz = {}
                # Liste vorbereiten für alle Grundstückbesitzer
                grundbesitzer = []


                driver.find_element_by_id('solrsearchFirstParamSelect').clear()
                driver.find_element_by_id('solrsearchFirstParamSelect').send_keys(liegenschaft_nr)
                time.sleep(0.5)

                eintraege = driver.find_elements_by_class_name('dijitReset.dijitMenuItem')
                for eintrag in eintraege:

                    # für jedes einzelne Grundstück

                    if eintrag.text != "Grundstücknummer: " + str(liegenschaft_nr): # Liegenschaftsnummer gibt es gar nicht
                        break



                    elif eintrag.text == "Grundstücknummer: " + str(liegenschaft_nr):
                        eintrag.click()
                        time.sleep(0.5)


                        # Anzeigefenster bestimmen, von wegen Mauspositionierung
                        anzeigefenster = driver.find_element_by_id('OpenLayers_Layer_Vector_RootContainer_57_svgRoot')
                        time.sleep(pause)
                        actions = ActionChains(driver)
                        actions.move_to_element(anzeigefenster).perform()
                        actions.move_by_offset(0, 0).click().perform()

                        time.sleep(pause) 

                        # Kartenmassstab lesen
                        # wenn Massstab-Angabe grösser als 50 m: Doppelklick, weil sonst Detailfenster nicht öffnet

                        massstab = driver.find_element_by_class_name('olControlScaleLineTop').text
                        while int(massstab[:-2]) > 50:
                            actions.move_to_element(anzeigefenster).perform()
                            actions.move_by_offset(0, 0).double_click().perform
                            actions.move_by_offset(0, 0).click().perform()
                            time.sleep(pause)
                            massstab = driver.find_element_by_class_name('olControlScaleLineTop').text
                            time.sleep(pause)
                            anzeigefenster = driver.find_element_by_id('OpenLayers_Layer_Vector_RootContainer_57_svgRoot')





                        # Auswahl der richtigen Infos (Besitzer und eben nicht Baurecht)
                        infotabs = driver.find_elements_by_class_name('dijitTitlePaneTextNode')
                        time.sleep(pause)



                        grundstueck_auswahl = 0
                        infotab_richtig = False

                        while infotab_richtig == False: # richtiger Tab anwählen, nämlich Liegenscaft, nicht Baurecht


                            grundstueck_nummer = driver.find_element_by_id('av_ls_chur_field_NUMMER_' + str(grundstueck_auswahl)).text # Nr. auslesen
                            time.sleep(pause)



                            if grundstueck_nummer == str(liegenschaft_nr): # im richtigen Infotab
                                infotab_richtig = True

                            else:
                                infotabs[grundstueck_auswahl].click() # Klick auf Infotab-element[grundstueck_auswahl]
                                grundstueck_auswahl = grundstueck_auswahl + 1
                                infotabs[grundstueck_auswahl].click() # Klick auf Infotab-element[grundstueck_auswahl]
                                time.sleep(pause)





                        # Infotab: Grundstück

                        # Suche nach Feld av_ls_chur_field_NUMMER_0 (wenn nur ein Infotab) oder
                        # av_ls_chur_field_NUMMER_1 (wenn zwei Infotabs respektive meh) > mit Variable grundstueck_auswahl

                        grundstueck_nummer = driver.find_element_by_id('av_ls_chur_field_NUMMER_' + str(grundstueck_auswahl)).text
                        time.sleep(pause)

                        grundstueck_typ = driver.find_element_by_id('av_ls_chur_field_GRUNDSTUECK_TYP_' + str(grundstueck_auswahl)).text
                        time.sleep(pause)

                        grundstueck_flaeche = driver.find_element_by_id('av_ls_chur_field_FLAECHE_NOMINAL_' + str(grundstueck_auswahl)).text
                        time.sleep(pause)
                        grundstueck_flaeche = int(re.sub(r"\b'\b", "", grundstueck_flaeche)) #Ersetzt alle Tausendertrennzeichen durch nichts

                        grundstueck_gemeinde = "Chur"
                        grundstueck_ort = "Chur"
                        grundstueck_koordinaten_x = 0
                        grundstueck_koordinaten_y = 0
                        time.sleep(pause)

                        # Infotab: Eigentümer

                        infotabs = driver.find_elements_by_xpath("//div[@role='presentation']")
                        time.sleep(pause)

                        for infotab in infotabs:
                            if infotab.text == ' Eigentümer ': # wenn Eigentümer-Feld
                                infotab.click()

                        time.sleep(pause)


                        besitzerinfo = driver.find_elements_by_class_name('infoWindowItemName')

                        # Loop für mehrere Eigentümer respektive Stockwerkeigentum


                        for nummer in range(0, len(besitzerinfo)-6):
                            # Elem 0 = leer
                            # Elem 1  = leer
                            # Elem 2 = leer
                            # Elem 3 = Gebäudenummer
                            # Elem 4 = Eigentumsart
                            # Elem 5 = Name
                            # Elem 6 = Vorname
                            # Elem 7 = Adresse
                            # Elem 8 = PLZ
                            # Elem 9 = Ort

                            # Elem 10 = Gebäudenummer etc. etc.

                            if besitzerinfo[nummer].text == str(liegenschaft_nr): # wenn Zyklus beginnt mit Angaben

                                eigentum_art = besitzerinfo[nummer + 1].text # Elem 4
                                eigentum_name = besitzerinfo[nummer + 2].text # Elem 5
                                eigentum_vorname = besitzerinfo[nummer + 3].text
                                eigentum_adresse = besitzerinfo[nummer + 4].text
                                eigentum_plz = besitzerinfo[nummer + 5].text
                                eigentum_ort = besitzerinfo[nummer + 6].text
                                eigentum_abfrage = datetime.now()

                                grundbesitz = {"Grundstueck-Nummer": grundstueck_nummer,
                                        "Grundstueck-Gemeinde": grundstueck_gemeinde,
                                        "Grundstueck-Ort": grundstueck_ort,
                                        "Grundstueck-Typ": grundstueck_typ,
                                        "Grundstueck-Flaeche": grundstueck_flaeche,
                                        "Grundstueck-Koordinate X": grundstueck_koordinaten_x,
                                        "Grundstueck-Koordinate Y": grundstueck_koordinaten_y,
                                        "Eigentumsart": eigentum_art,
                                        "Name": eigentum_name,
                                        "Vorname": eigentum_vorname,
                                        "Adresse": eigentum_adresse,
                                        "PLZ": eigentum_plz,
                                        "Ort": eigentum_ort,
                                        "Datum der Abfrage": eigentum_abfrage}

                                grundbesitzer.append(grundbesitz)


                        besitzer = pd.DataFrame(grundbesitzer)            
                        headernames = ['Grundstueck-Nummer', 'Grundstueck-Gemeinde', 'Grundstueck-Ort', 'Grundstueck-Typ', 'Grundstueck-Flaeche', 'Grundstueck-Koordinate X', 'Grundstueck-Koordinate Y', 'Eigentumsart', 'Name', 'Vorname', 'Adresse', 'PLZ', 'Ort', 'Datum der Abfrage']

                        file_name = grundstueck_gemeinde + '_' + str('0000000000' + grundstueck_nummer)[-10:]
                        besitzer.to_csv('grundstuecke/' + file_name + '.csv', header=headernames, sep=";", index=False)

                        grundstueck_ausgelesen.append(liegenschaft_nr)




            except: # FEHLER AUFGETRETEN bei Aufruf einer Grundstücknummer

                # in liste eintragen, später manuell machen
                grundstueck_manuell_bearbeiten.append(liegenschaft_nr)

                with open('grundstuecke/Chur_manuell_bearbeiten.csv', 'w+') as csvfile:
                    writer = csv.writer(csvfile, delimiter='\n')
                    writer.writerows([grundstueck_manuell_bearbeiten])    
                csvfile.close()








    driver.close()
# Out:
# Durchlauf 1 von 1

# %% [markdown]
# # ab hier Einzelabfrage jener Grundstücke, die in Chur_manuell_bearbeiten.csv gelistet sind

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')
driver.get('https://stadtplan.chur.ch/mapplus/chur/index.php?lang=de&basemap=av_schwarz&blop=1&x=2759663.1205041&y=1191084.0553479&zl=11&hl=0&layers=AV_Bauprojekte_bewilligt|AV_Baulinien&theme=1')

# %%
# Abruf, wenn manuell richtiges Grundstück angewählt und Infos angezeigt werden

# Infotab: Grundstück

# Suche nach Feld av_ls_chur_field_NUMMER_0 (wenn nur ein Infotab) oder
# av_ls_chur_field_NUMMER_1 (wenn zwei Infotabs respektive meh) > mit Variable grundstueck_auswahl


grundbesitz = {}
grundbesitzer = []



grundstueck_nummer = driver.find_element_by_id('av_ls_chur_field_NUMMER_' + str(0)).text
time.sleep(pause)

grundstueck_typ = driver.find_element_by_id('av_ls_chur_field_GRUNDSTUECK_TYP_' + str(0)).text
time.sleep(pause)

grundstueck_flaeche = driver.find_element_by_id('av_ls_chur_field_FLAECHE_NOMINAL_' + str(0)).text
time.sleep(pause)

grundstueck_flaeche = int(re.sub(r"\b'\b", "", grundstueck_flaeche)) #Ersetzt alle Tausendertrennzeichen durch nichts

grundstueck_gemeinde = "Chur"
grundstueck_ort = "Chur"
grundstueck_koordinaten_x = 0
grundstueck_koordinaten_y = 0
time.sleep(pause)

# Infotab: Eigentümer

infotabs = driver.find_elements_by_xpath("//div[@role='presentation']")
time.sleep(pause)

for infotab in infotabs:
    if infotab.text == ' Eigentümer ': # wenn Eigentümer-Feld
        infotab.click()

time.sleep(pause)


besitzerinfo = driver.find_elements_by_class_name('infoWindowItemName')
time.sleep(pause)
# Loop für mehrere Eigentümer respektive Stockwerkeigentum


for nummer in range(0, len(besitzerinfo)-6):
                            # Elem 0 = leer
                            # Elem 1  = leer
                            # Elem 2 = leer
                            # Elem 3 = Gebäudenummer
                            # Elem 4 = Eigentumsart
                            # Elem 5 = Name
                            # Elem 6 = Vorname
                            # Elem 7 = Adresse
                            # Elem 8 = PLZ
                            # Elem 9 = Ort

                            # Elem 10 = Gebäudenummer etc. etc.

    if besitzerinfo[nummer].text == str(grundstueck_nummer): # wenn Zyklus beginnt mit Angaben

        eigentum_art = besitzerinfo[nummer + 1].text # Elem 4
        eigentum_name = besitzerinfo[nummer + 2].text # Elem 5
        eigentum_vorname = besitzerinfo[nummer + 3].text
        eigentum_adresse = besitzerinfo[nummer + 4].text
        eigentum_plz = besitzerinfo[nummer + 5].text
        eigentum_ort = besitzerinfo[nummer + 6].text
        eigentum_abfrage = datetime.now()

        grundbesitz = {"Grundstueck-Nummer": grundstueck_nummer, 
                "Grundstueck-Gemeinde": grundstueck_gemeinde,
                "Grundstueck-Ort": grundstueck_ort,
                "Grundstueck-Typ": grundstueck_typ,
                "Grundstueck-Flaeche": grundstueck_flaeche,
                "Grundstueck-Koordinate X": grundstueck_koordinaten_x,
                "Grundstueck-Koordinate Y": grundstueck_koordinaten_y,
                "Eigentumsart": eigentum_art,
                "Name": eigentum_name,
                "Vorname": eigentum_vorname,
                "Adresse": eigentum_adresse,
                "PLZ": eigentum_plz,
                "Ort": eigentum_ort,
                "Datum der Abfrage": eigentum_abfrage}

        grundbesitzer.append(grundbesitz)


besitzer = pd.DataFrame(grundbesitzer)            
headernames = ['Grundstueck-Nummer', 'Grundstueck-Gemeinde', 'Grundstueck-Ort', 'Grundstueck-Typ', 'Grundstueck-Flaeche', 'Grundstueck-Koordinate X', 'Grundstueck-Koordinate Y', 'Eigentumsart', 'Name', 'Vorname', 'Adresse', 'PLZ', 'Ort', 'Datum der Abfrage']

file_name = grundstueck_gemeinde + '_' + str('0000000000' + grundstueck_nummer)[-10:]
besitzer.to_csv('grundstuecke/' + file_name + '.csv', header=headernames, sep=";", index=False)

# %% [markdown]
# # alle csv-Dateien in ein Pandaframe einfügen, abspeichern

# %%
import pandas as pd
import glob

# Liste aller csv
csv_files = glob.glob('grundstuecke/' + '*.csv')
len(csv_files)
# Out:
# 6708

# %%
# CSV öffnen, in Liste alle_dfs

alle_dfs = []
for csv_file in csv_files:
    dfs = pd.read_csv(csv_file, sep=';')
    
    alle_dfs.append(dfs)

# %%
alle_daten = pd.concat(alle_dfs)

# %%
alle_daten.tail(5)
# Out:
#    Grundstueck-Nummer Grundstueck-Gemeinde Grundstueck-Ort  \
# 0                4810                 Chur            Chur
# 0                4804                 Chur            Chur
# 0                8958                 Chur            Chur
# 0                6975                 Chur            Chur
# 1                6975                 Chur            Chur
#
#          Grundstueck-Typ  Grundstueck-Flaeche  Grundstueck-Koordinate X  \
# 0           Liegenschaft                 1443                         0
# 0           Liegenschaft                 1237                         0
# 0  SelbstRecht, Baurecht                  173                         0
# 0           Liegenschaft                  379                         0
# 1           Liegenschaft                  379                         0
#
#    Grundstueck-Koordinate Y    Eigentumsart                 Name Vorname  \
# 0                         0  Alleineigentum           Stadt Chur     NaN
# 0                         0  Alleineigentum             Hartmann    Jürg
# 0                         0  Alleineigentum  Kieswerk Calanda AG     NaN
# 0                         0     Miteigentum                 Lang  Eduard
# 1                         0     Miteigentum                 Lang   Luzia
#
#             Adresse   PLZ   Ort           Datum der Abfrage
# 0               NaN   NaN   NaN  2020-01-10 21:10:23.581426
# 0   Prasserieweg 10  7000  Chur  2020-01-10 21:09:01.287635
# 0  Rheinstrasse 219  7000  Chur  2019-12-30 07:57:47.182660
# 0   Brändligasse 18  7000  Chur  2019-12-30 04:39:55.996836
# 1   Brändligasse 18  7000  Chur  2019-12-30 04:39:56.157998

# %%
alle_daten.dtypes
# Out:
# Grundstueck-Nummer           int64
# Grundstueck-Gemeinde        object
# Grundstueck-Ort             object
# Grundstueck-Typ             object
# Grundstueck-Flaeche          int64
# Grundstueck-Koordinate X     int64
# Grundstueck-Koordinate Y     int64
# Eigentumsart                object
# Name                        object
# Vorname                     object
# Adresse                     object
# PLZ                         object
# Ort                         object
# Datum der Abfrage           object
# dtype: object

# %%
# mit concat in ein Dataframe

alle_csv = pd.concat(dfs, ignore_index=False)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # ab hier ein paar mögliche Abfragen

# %%
alle_csv[(alle_csv['Name'] == 'Domenig') & (alle_csv['Vorname'] != 'Bruno')]
# Out:
#     2967               Adresse           Datum der Abfrage  \
# 8    NaN       Florastrasse 15  2020-01-17 18:07:10.620812
# 6    NaN  Wiesentalstrasse 214  2020-01-07 16:00:29.296873
# 1    NaN   Tschuggenstrasse 51  2019-12-28 20:20:17.683956
# 0    NaN   Tschuggenstrasse 51  2019-12-28 15:44:13.354876
# 3    NaN       Kornquaderweg 8  2020-01-07 15:44:26.301965
# 4    NaN       Kornquaderweg 8  2020-01-07 15:44:26.455816
# 5    NaN       Kornquaderweg 8  2020-01-07 15:44:26.579512
# 6    NaN       Kornquaderweg 8  2020-01-07 15:44:26.705064
# 0    NaN   Tschuggenstrasse 51  2019-12-28 20:18:24.349013
# 4    NaN              Matätsch  2019-12-29 19:36:04.245840
# 5    NaN              Strela 4  2019-12-29 19:36:04.359947
# 13   NaN                   NaN  2019-12-29 18:52:28.196236
# 0    NaN         Loestrasse 85  2019-12-30 13:21:38.352760
# 1    NaN         Loestrasse 85  2019-12-30 13:21:38.466288
# 1    NaN   Tschuggenstrasse 51  2019-12-30 20:00:12.783708
# 0    NaN        Werkstrasse 15  2020-01-02 19:23:30.433130
# 8    NaN   Segantinistrasse 11  2020-01-10 06:03:32.634769
# 9    NaN        Werkstrasse 15  2020-01-10 06:03:32.752153
# 10   NaN         Loestrasse 85  2020-01-10 06:03:32.905018
# 0    NaN  Wiesentalstrasse 214  2019-12-30 18:11:21.586301
# 7    NaN                   NaN  2020-01-10 15:57:31.775655
# 8    NaN                   NaN  2020-01-10 15:57:31.901889
# 0    NaN   Tschuggenstrasse 51  2019-12-30 02:17:33.677248
# 0    NaN   Tschuggenstrasse 51  2019-12-30 02:15:44.474881
# 30   NaN        Werkstrasse 15  2019-12-30 02:29:09.879737
# 0    NaN                   NaN  2019-12-29 20:24:59.660422
# 0    NaN       Florastrasse 15  2019-12-29 04:39:14.690861
# 49   NaN       Kornquaderweg 8  2020-01-21 10:36:30.423443
# 50   NaN       Kornquaderweg 8  2020-01-21 10:36:30.573494
# 0    NaN              Strela 4  2020-01-14 23:02:12.572321
# 0    NaN   Tschuggenstrasse 51  2019-12-28 16:08:32.213862
# 15   NaN                   NaN  2019-12-29 20:35:07.784138
# 0    NaN   Tschuggenstrasse 51  2019-12-30 16:35:42.088984
# 1    NaN   Tschuggenstrasse 51  2019-12-30 16:35:42.229820
# 0    NaN   Tschuggenstrasse 51  2020-01-01 10:54:01.489342
# 0    NaN                   NaN  2020-01-10 16:14:02.412510
# 15   NaN                   NaN  2020-01-10 16:14:19.947593
# 0    NaN                   NaN  2020-01-10 16:13:46.763835
# 15   NaN                   NaN  2020-01-21 10:37:33.221579
#
#                        Eigentumsart  Grundstueck-Flaeche Grundstueck-Gemeinde  \
# 8   Unselbstständiges Grundeigentum                489.0                 Chur
# 6                       Miteigentum                398.0                 Chur
# 1                       Miteigentum                375.0                 Chur
# 0                    Alleineigentum               2590.0                 Chur
# 3                 Stockwerkeigentum               2124.0                 Chur
# 4                 Stockwerkeigentum               2124.0                 Chur
# 5                 Stockwerkeigentum               2124.0                 Chur
# 6                 Stockwerkeigentum               2124.0                 Chur
# 0                       Miteigentum               3521.0                 Chur
# 4                 Stockwerkeigentum               4303.0                 Chur
# 5                 Stockwerkeigentum               4303.0                 Chur
# 13                      Miteigentum               1077.0                 Chur
# 0                 Stockwerkeigentum                621.0                 Chur
# 1                 Stockwerkeigentum                621.0                 Chur
# 1                       Miteigentum              18667.0                 Chur
# 0                 Stockwerkeigentum               1106.0                 Chur
# 8                 Stockwerkeigentum               2494.0                 Chur
# 9                 Stockwerkeigentum               2494.0                 Chur
# 10                Stockwerkeigentum               2494.0                 Chur
# 0                    Alleineigentum                707.0                 Chur
# 7                       Miteigentum                360.0                 Chur
# 8                       Miteigentum                360.0                 Chur
# 0                    Gesamteigentum                532.0                 Chur
# 0                    Gesamteigentum               1452.0                 Chur
# 30                      Miteigentum                 15.0                 Chur
# 0                    Alleineigentum                508.0                 Chur
# 0                    Alleineigentum                590.0                 Chur
# 49                      Miteigentum               6830.0                 Chur
# 50                      Miteigentum               6830.0                 Chur
# 0                    Alleineigentum                478.0                 Chur
# 0                       Miteigentum               3257.0                 Chur
# 15  Unselbstständiges Grundeigentum                409.0                 Chur
# 0                       Miteigentum                560.0                 Chur
# 1                       Miteigentum                560.0                 Chur
# 0                       Miteigentum              14303.0                 Chur
# 0                    Alleineigentum                445.0                 Chur
# 15  Unselbstständiges Grundeigentum                364.0                 Chur
# 0                    Alleineigentum                349.0                 Chur
# 15  Unselbstständiges Grundeigentum               4084.0                 Chur
#
#     Grundstueck-Koordinate X  Grundstueck-Koordinate Y  Grundstueck-Nummer  \
# 8                        0.0                       0.0              3380.0
# 6                        0.0                       0.0              6366.0
# 1                        0.0                       0.0              1596.0
# 0                        0.0                       0.0               461.0
# 3                        0.0                       0.0              5866.0
# 4                        0.0                       0.0              5866.0
# 5                        0.0                       0.0              5866.0
# 6                        0.0                       0.0              5866.0
# 0                        0.0                       0.0              1590.0
# 4                        0.0                       0.0              5792.0
# 5                        0.0                       0.0              5792.0
# 13                       0.0                       0.0              5551.0
# 0                        0.0                       0.0             10835.0
# 1                        0.0                       0.0             10835.0
# 1                        0.0                       0.0             13486.0
# 0                        0.0                       0.0              6711.0
# 8                        0.0                       0.0              3671.0
# 9                        0.0                       0.0              3671.0
# 10                       0.0                       0.0              3671.0
# 0                        0.0                       0.0             12620.0
# 7                        0.0                       0.0              5613.0
# 8                        0.0                       0.0              5613.0
# 0                        0.0                       0.0              6694.0
# 0                        0.0                       0.0              6690.0
# 30                       0.0                       0.0              6724.0
# 0                        0.0                       0.0              5920.0
# 0                        0.0                       0.0              3376.0
# 49                       0.0                       0.0              5868.0
# 50                       0.0                       0.0              5868.0
# 0                        0.0                       0.0             20154.0
# 0                        0.0                       0.0               534.0
# 15                       0.0                       0.0              5935.0
# 0                        0.0                       0.0             12093.0
# 1                        0.0                       0.0             12093.0
# 0                        0.0                       0.0              1589.0
# 0                        0.0                       0.0              5926.0
# 15                       0.0                       0.0              5927.0
# 0                        0.0                       0.0              5925.0
# 15                       0.0                       0.0              5924.0
#
#    Grundstueck-Ort        Grundstueck-Typ     Name       Ort   PLZ  \
# 8             Chur           Liegenschaft  Domenig      Chur  7000
# 6             Chur           Liegenschaft  Domenig      Chur  7000
# 1             Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 3             Chur  SelbstRecht, Baurecht  Domenig      Chur  7000
# 4             Chur  SelbstRecht, Baurecht  Domenig      Chur  7007
# 5             Chur  SelbstRecht, Baurecht  Domenig      Chur  7000
# 6             Chur  SelbstRecht, Baurecht  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 4             Chur  SelbstRecht, Baurecht  Domenig  Maladers  7026
# 5             Chur  SelbstRecht, Baurecht  Domenig  Maladers  7026
# 13            Chur           Liegenschaft  Domenig   Omaruru   NaN
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 1             Chur           Liegenschaft  Domenig      Chur  7000
# 1             Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 8             Chur           Liegenschaft  Domenig      Chur  7000
# 9             Chur           Liegenschaft  Domenig      Chur  7000
# 10            Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 7             Chur  SelbstRecht, Baurecht  Domenig      Chur  7000
# 8             Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 30            Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 49            Chur  SelbstRecht, Baurecht  Domenig      Chur  7007
# 50            Chur  SelbstRecht, Baurecht  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig  Maladers  7026
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 15            Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 1             Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur           Liegenschaft  Domenig      Chur  7000
# 0             Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
# 15            Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
# 0             Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
# 15            Chur  SelbstRecht, Baurecht  Domenig   Omaruru   NaN
#
#             Vorname
# 8          Johannes
# 6     Thomas Markus
# 1       Irina Maria
# 0       Irina Maria
# 3             Ernst
# 4          Francois
# 5   Maja Margaretha
# 6     Monica Angela
# 0       Irina Maria
# 4   Enna Margherite
# 5             Roman
# 13    Thomas Markus
# 0            Evelyn
# 1         Urs Georg
# 1       Irina Maria
# 0              Jürg
# 8             Georg
# 9              Jürg
# 10        Urs Georg
# 0     Thomas Markus
# 7            Thomas
# 8     Thomas Markus
# 0       Irina Maria
# 0       Irina Maria
# 30             Jürg
# 0     Thomas Markus
# 0          Johannes
# 49         Francois
# 50  Maja Margaretha
# 0             Roman
# 0       Irina Maria
# 15    Thomas Markus
# 0       Irina Maria
# 1        Jon Andrea
# 0       Irina Maria
# 0     Thomas Markus
# 15    Thomas Markus
# 0     Thomas Markus
# 15    Thomas Markus

# %%
alle_csv['Name'].value_counts().head(10)
# Out:
# Stadt Chur                      926
# Schmid                          151
# Hassler                         133
# Kanton Graubünden               114
# Caflisch                        109
# Bürgergemeinde Chur             102
# Hartmann                         92
# Politische Gemeinde Maladers     84
# Brunold                          80
# Müller                           79
# Name: Name, dtype: int64

# %%
df.groupby('Institution Country')['Approved Amount'].mean().sort_values(ascending=False).head(10)
